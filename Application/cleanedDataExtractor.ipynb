# %%
import json
import re
import ast

pattern = r"\[.*\]"
with open("F1_score_calculator.ipynb") as file:
    jsonContent = json.load(file)
answerList = []
for i in jsonContent['cells']:
    a = [j for j in i['source'] if "answer" in j][0]
    b = ast.literal_eval(re.search(pattern, a)[0])
    answerList.append(b)
print(answerList)
# Out:
# [['challenging patient', 'uncooperative behavior', 'noncompliant', 'frequent cursing at nurses', 'difficult patient', 'challenging interactions', 'unreliable historical recounting', 'refused several exams', 'resistant to modifying his diet', 'noncompliance has been a significant barrier to his care'], ['uncooperative with blood draws and other procedures', 'pattern of noncompliance', 'refused several exams', 'refused exams and medication administration', 'complicating her treatment plans', 'compliance issues raise concern for her overall management', 'encouraged to address these compliance issues'], ['challenging patient', 'particularly difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'complicating the assessment', 'compliance issues throughout her stay', 'refusing medications', 'declining exams', 'noncompliant behavior', 'delaying discharge', 'difficult'], ['non-compliant', 'refused examination and medication adjustments', 'difficult and challenging patient', 'cursing at staff', 'displaying inconsistent historical reporting'], ['difficult attitude towards staff', 'resistant to dietary advice', 'challenging to manage in terms of medication regimen adherence', 'noncompliant with multiple recommended changes to her lifestyle'], ['difficult and noncompliant patient', 'frequent visitor to our ED', 'demonstrated a pattern of nonadherence to prescribed diabetic medications', 'refuses to modify his diet', 'refused blood work', 'appears noncompliant', 'refusal to follow the medical advice', 'noncompliance with diabetes management requirements'], ['noncompliant with prescribed treatments in the past', 'frequent ED visits for similar symptoms', 'lack of cooperation during his stay', 'resisting routine checks and medications', 'challenging patient due to his past nonadherence', 'refusal to complete exams', 'inconsistent use of medication', 'past nonadherence'], ['vague and contradictory responses', 'noncompliant patient', 'frequent previous admissions for unrelated complaints', 'refusal of initial pain management suggestions', 'known difficult case', 'noncompliance to medical advice', 'frequent smoker', 'refusal for diagnostic imaging'], ['obesity', 'poorly controlled hypertension', 'medication nonadherence', 'resistant to suggestions for improvement', 'difficulty adhering to a healthier lifestyle', 'appears overweight', 'obese', 'lack of engagement in recommended lifestyle changes', 'resistance to mental health discussions', 'noncompliance'], ['chronic pain', 'history of narcotic dependence', 'resistant to alternative pain management strategies', 'nonadherence to recommended medication adjustments', 'compliance issues', 'chronic pain syndrome', 'relapse into previous narcotic dependency', 'avoid frequent emergency department visits', 'challenging', 'difficult behaviors towards staff'], ['drug overdose', 'previous overdoses', 'narcotic dependence', 'medication nonadherence', 'challenging with staff', 'difficult to engage in her own care plan', 'evidence of narcotic dependence', 'opioid overdose', 'guarded mental status', 'tapering schedule for her narcotic medications', 'substance use disorder treatment', 'refused'], ['chronic complainer', 'noncompliant with medication regimes', 'refusal to adhere to treatment protocols', 'poorly managed self-care', 'resistance to proposed treatment options', 'uncooperative', 'difficult course', 'frequent noncompliance', 'noncompliant', 'requires your cooperation', 'refuses to quantify'], ['nonadherent with her prescribed medication regimen', 'frequently visits the ED for similar complaints', 'history of alcohol misuse ("Alcoholic")', 'described as a difficult patient', 'challenging attitude', 'noncompliant nature', 'alcoholic tendencies', 'markedly worsened by nonadherence to your prescribed medication regimen', 'alcohol misuse', 'refusing', 'declined completing several examinations'], ['narcotic dependency', 'difficult', 'noncompliant', 'cha ...

# %%
import ast
with open("ollama31Output.txt") as file:
    a = file.read().split("\n")
    chat=[]
    for i in a[:50]:
        chat.append(ast.literal_eval(i))
        print(i)
print(chat)
# Out:
# ['challenging', 'uncooperative behavior', 'noncompliant', 'frequent episodes of cursing at healthcare staff', 'difficult patient', 'refused several exams', 'resistant to modifying his diet', 'poor dietary habits', 'idiotic short stature']
# ['noncompliant', 'nonadherent', 'uncooperative', 'refusing exams and medication administration', 'compliance issues']
# ['challenging', 'difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'making the assessment more complicated than necessary', 'resistant during the exam', 'inconsistent in narration', 'exhibited compliance issues throughout her stay', 'refusing medications and declining exams', 'noncompliant behavior', 'delayed discharge', 'difficult']
# ['non-compliant', 'frequently missed follow-up appointments', 'medication adherence issues', 'frustration about medical advice provided', 'showing a pattern of medication adherence issues', 'alcohol over the recommended guidelines', 'social gatherings often revolve around drinking', 'difficult and challenging patient', 'cursing at staff during examination', 'displaying inconsistent historical reporting', 'refused examination and medication adjustments', 'claimed he knew his body better than any doctor']
# ['difficult attitude', 'resistant to dietary advice', 'challenging to manage', 'nonadherent', 'declining to participate fully', 'noncompliant']
# ['difficult', 'noncompliant', 'frequent visitor to ED', 'refuses', 'poorly controlled blood glucose levels', 'nonadherence', 'uncooperative']
# ['noncompliant', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'inconsistent responses']
# ['difficult case', 'noncompliance to medical advice', 'vague and contradictory responses', 'met with vagueness and contradiction', 'reluctant to cooperate', 'agitated and reluctant to cooperate', 'patient non-cooperation', 'uncooperative', 'frequent previous admissions for unrelated complaints', 'difficult and noncompliant patient']
# ['nonadherence', 'resistant', 'medication nonadherence', 'poorly controlled hypertension likely due to medication nonadherence', 'difficulty adhering to a healthier lifestyle', 'noncompliance with a healthy lifestyle', 'overweight', 'obese']
# ['nonadherent', 'resistant', 'compliance issues', 'difficult behavior', 'narcotic dependence']
# ['frequent visitor to ED', 'narcotic dependence', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'disheveled appearance']
# ['chronic complainer', 'adherence to prescribed medical advice remains questionable', "patient's adherence to prescribed medical regimes", 'noncompliant with medication regimes', 'non-relevant', 'uncooperative']
# ['nonadherent', 'frequently visits the ED for similar complaints', 'Alcoholic', 'difficult patient', 'refusing recommended examinations and treatments', 'noncompliance with medical advice', 'difficult attitude', 'challenging attitude', 'poor asthma management', 'poor health status']
# ['narcotic dependency', 'difficult', 'noncompliant', 'challenging to deal with', 'inconsistent historian', 'medication nonadherence', 'frequent user']
# ['nonadherence', 'noncompliance', 'poorly managed diabetes', 'frequently mentions going out, indicating a lack of compliance with dietary restrictions', 'Shows a pattern of medication nonadherence', 'resistant to implementing suggested changes']
# ['noncompliance', 'resistant behavior', 'challenging management', 'poorly controlled hypertension attributed to noncompliance with medication', 'uncooperative', 'inconsistent responses']
# ['difficult', 'noncompliant', 'challenging', 'refused', 'resistant', 'poorly managed', 'poorly controlled', 'nonadherent', 'uncooperative']
# ['difficult to manage', 'noncompliance with treatment protocols', 'refusing exams', 'ignoring medical advice', 'noncompliant with prescribed growth hormone therapy', 'frequent visits to the emergency department for minor complaints', 'involvement in frequent altercations at school', 'noncompliant attitude towards recommended interventions', 'complicating the treatment process']
# ['noncompliant', 'nonadherent', 'resistant', 'uncooperative', 'reluctant', 'frustrated']
# ['noncompliant', 'medication nonadherence', 'failure to attend scheduled follow-ups', 'frequent visitor to ED', 'lack of primary care engagement', 'challenging', 'contradictory statements', 'difficult', 'uncooperative']
# ['noncompliant', 'uncooperative', 'challenged', 'resistant', 'refusal', 'nonadherence']
# ['noncompliant', 'difficulty', 'nonadherence', 'refusing', 'contradiction', 'complicated']
# ['noncompliance', 'difficult patient', 'refusing several exams', 'nonadherence', 'contradicts medical advice']
# ['challenging', 'noncompliance', 'nonadherence', 'resistance to dietary and medication adjustments', 'recurrent refusal to follow medical advice', 'frequent visitor to ED for minor complaints', 'poorly controlled hypertension', 'Type 2 diabetes ', 'smoking history ', 'obese']
# ['difficult', 'known history of COPD', 'nonadherence', 'heavy smoker', 'medication nonadherent', 'noncooperative', 'challenging', 'refused to provide detailed information', 'hanging out around McDonald’s frequently', 'difficult to engage in productive discussion', 'appears older than stated age, challenging demeanor', 'noncompliant with cognitive testing', 'medication nonadherence and often refusing to complete exams or engage in treatments']
# ['noncompliant', 'nonadherent', 'challenging', 'inconsistent responses', 'difficult patient']
# ['noncompliance', 'refusal to adhere', 'resistant', 'challenging', 'contradictory descriptions', 'difficulty providing clear timeline of symptoms']
# ['nonadherence', 'noncompliance', 'uncooperative']
# ['poor control', 'nonadherence', 'refusal of insulin therapy', 'contradicting statements', 'recurrent high A1c levels', 'difficulty maintaining consistent medical appointments', 'noncompliant', 'challenging', 'inconsistent responses', 'refused a planned exam claiming it unnecessary', 'contradictory statements about diet and medication adherence', 'could deteriorate into more severe complications']
# ['obese', 'noncompliant behavior', 'resistant and challenging attitude', 'remains noncompliant', 'poor diabetes management', 'non-compliance only complicates your condition']
# ['noncompliant', 'refused', 'difficult to ascertain due to patient noncompliance', 'lack of cooperation from the patient and her guardians', "patient's refusal to provide an accurate history", 'uncooperative during the exam and interviews', 'challenging at times', 'nonadherence']
# ['difficult', 'resistant', 'contradicting herself', 'noncompliant with school regulations', 'noncompliance with recommended diagnostic procedures', 'challenging behavior', 'refused treatment', 'resistance towards medical advice', 'noncompliance with recommended genetic counseling']
# ['alcoholic', 'narcotic-dependent', 'difficult', 'resistant', 'vague', 'inconsistent', 'noncompliant', 'challenging', 'refused', 'contradicting themselves', 'frequent visitor to ED', 'obese']
# ['nonadherent', 'noncompliant', 'refused', 'contradicting themselves']
# ['challenging', 'nonadherent', 'compliance issues', 'difficulty managing', 'resistant to medical advice']
# ['noncompliant', 'inconsistent responses', 'difficulties in assessing lifestyle contributions', 'challenging behavior', 'medication nonadherence', 'refusal to follow prescribed nutritional guidance', 'contradicting previously provided information', 'constituted growth delay compounded by noncompliance with nutritional recommendations']
# ['noncompliant', 'nonadherent', 'difficult', 'challenging', 'refused']
# ['non-adherence', 'noncompliance', 'poor choices', 'failing', 'often foregoing medication', 'neglect', 'regular blood pressure monitoring', 'lifestyle adjustments', 'new medication regimens', 'resistant to suggestions', 'reluctance towards', 'medication adherence', 'variable success due to similar compliance issues', 'uncontrolled hypertension secondary to medication nonadherence', 'limited by obesity']
# ['narcotic dependent', 'noncompliant', 'difficult patient', 'refusal to undergo recommended exams initially', 'challenging']
# ['so-called', 'frequent ED visitor', 'noncompliant demeanor', 'poorly managed', 'inconsistent medication adherence', 'claimed discomfort', 'challenging behavior', 'noncompliant behavior', 'misunderstandings about her medication adherence', 'inconsistent historian with medication nonadherence', 'seizure disorder management', 'somewhat noncompliant']
# ['difficult patient', 'ignored medical advice', 'noncompliant', 'resistant to suggestions for improving her health', 'failing to follow up on recommended tests', 'ignoring dietary advice', 'uncooperative with staff', 'frequently refusing to provide necessary history or allow physical examination', 'noncompliance and resistance to discussing potential preventative measures for future pregnancies made counseling challenging', 'resistant', 'previous refusal to accept medical advice']
# ['noncompliant', 'difficult patient', 'frequents fast-food restaurants', 'in ED frequently', 'refused exam']
# ['notably obese', 'noncompliance', 'nonadherent', 'difficult patient', 'challenging patient', 'refusing dietary adjustments', 'frequent consumption of fast food', 'non-compliant with previous dietary counseling', 'limited physical activity noted', 'medication nonadherence', 'obese, appears his stated age', 'poorly controlled diabetes', 'challenging attitude towards the medical staff', 'repeated refusal to participate in recommended physical therapy sessions', 'noncompliance and medication adherence issues have been a recurrent theme']
# ['noncompliance', 'disregard for prior medical advice', 'resistant attitude towards treatment', 'frequent flyer', 'difficulty in managing the patient due to inconsistent history reporting', 'refusal to undergo recommended examination procedures initially', 'inconsistent responses']
# ['difficult patient', 'nonadherent', 'noncompliant', 'frequent visitor to ED']
# ['stubborn eating habits', 'refusal to adhere to dietary recommendations', 'resistant', 'difficult case due to noncompliance with dietary and medication regimes', 'nonadherence to treatment plans', 'challenging', 'frequently missing appointments', 'resisting dietary adjustments necessary for his condition', 'frequent flyer status in our clinic', 'medication runs out or is not taken as prescribed', 'history of noncompliance and resistance to medical advice']
# ['disconcerting', 'difficult', 'contradictions', 'resistance', 'complicating', 'attention-seeking behavior', 'conflicting information', 'noncompliant', 'refusals for recommended exams', 'impeded his care plan', 'challenging behavior', 'stable but noncompliant']
# ['noncompliance', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'contradicting themselves']
# ['obesity', 'noncompliance', 'difficult patient', 'disruptive pattern of behavior', 'reluctance to discuss or engage in mental health support options', 'weight significantly above ideal for height']
# ['nonadherent', 'refuses to seek early treatment', 'often refuses to seek early treatment', 'noncompliant with previous advice to quit', 'challenging attitude towards treatment', 'challenging behavior during this hospital stay', 'noncompliance has delayed his recovery process']
# [['challenging', 'uncooperative behavior', 'noncompliant', 'frequent episodes of cursing at healthcare staff', 'difficult patient', 'refused several exams', 'resistant to modifying his diet', 'poor dietary habits', 'idiotic short stature'], ['noncompliant', 'nonadherent', 'uncooperative', 'refusing exams and medication administration', 'compliance issues'], ['challenging', 'difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'making the assessment more complicated than necessary', 'resistant during the exam', 'inconsistent in narration', 'exhibited compliance issues throughout her stay', 'refusing medications and declining exams', 'noncompliant behavior', 'delayed discharge', 'difficult'], ['non-compliant', 'frequently missed follow-up appointments', 'medication adherence issues', 'frustration about medical advice provided', 'showing a pattern of medication adherence issues', 'alcohol over the recommended guidelines', 'social gatherings often revolve around drinking', 'difficult and challenging patient', 'cursing at staff during examination', 'displaying inconsistent historical reporting', 'refused examination and medication adjustments', 'claimed he knew his body better than any doctor'], ['difficult attitude', 'resistant to dietary advice', 'challenging to manage', 'nonadherent', 'declining to participate fully', 'noncompliant'], ['difficult', 'noncompliant', 'frequent visitor to ED', 'refuses', 'poorly controlled blood glucose levels', 'nonadherence', 'uncooperative'], ['noncompliant', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'inconsistent responses'], ['difficult case', 'noncompliance to medical advice', 'vague and contradictory responses', 'met with vagueness and contradiction', 'reluctant to cooperate', 'agitated and reluctant to cooperate', 'patient non-cooperation', 'uncooperative', 'frequent previous admissions for unrelated complaints', 'difficult and noncompliant patient'], ['nonadherence', 'resistant', 'medication nonadherence', 'poorly controlled hypertension likely due to medication nonadherence', 'difficulty adhering to a healthier lifestyle', 'noncompliance with a healthy lifestyle', 'overweight', 'obese'], ['nonadherent', 'resistant', 'compliance issues', 'difficult behavior', 'narcotic dependence'], ['frequent visitor to ED', 'narcotic dependence', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'disheveled appearance'], ['chronic complainer', 'adherence to prescribed medical advice remains questionable', "patient's adherence to prescribed medical regimes", 'noncompliant with medication regimes', 'non-relevant', 'uncooperative'], ['nonadherent', 'frequently visits the ED for similar complaints', 'Alcoholic', 'difficult patient', 'refusing recommended examinations and treatments', 'noncompliance with medical advice', 'difficult attitude', 'challenging attitude', 'poor asthma management', 'poor health status'], ['narcotic dependency', 'difficult', 'noncompliant', 'challenging to deal with', 'inconsistent historian', 'medication nonadherence', 'frequent user'], ['nonadherence', 'noncompliance', 'poorly managed diabetes', 'frequently mentions going out, indicating a lack of compliance with dietary restrictions', 'Shows a pattern of medication nonadherence', 'resistant to implementing suggested changes'], ['noncompliance', 'resistant behavior', 'challenging management', 'poorly controlled hypertension attributed to noncompliance with medication', 'uncooperative', 'inconsistent responses'], ['difficult', 'noncompliant', 'challenging', 'refused', 'resistant', 'poorly managed', 'poorly controlled', 'nonadherent', 'uncooperative'], ['difficult to manage', 'noncompliance with treatment protocols', 'refusing exams', 'ignoring medical advice', 'noncompliant with prescribed growth hormone therapy', 'frequent visits to the emergency department for minor complaints', 'involvement in frequent altercations at school', 'noncompliant attitude  ...

# %%
import nbformat as nbf

nb = nbf.v4.new_notebook()

for index in range(0, 50):
    code = f"""import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[{index}]["Completion"]

chat2 = {chat[index]}

answer2 = {answerList[index]}

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)"""
    nb.cells.append(nbf.v4.new_code_cell(code))

with open("ollamaF1Scorer.ipynb", "w", encoding="utf-8") as f:
    nbf.write(nb, f)

print("finished writing")
# Out:
# finished writing
