# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[0]["Completion"]

chat2 = ['challenging', 'uncooperative behavior', 'noncompliant', 'frequent episodes of cursing at healthcare staff', 'difficult patient', 'refused several exams', 'resistant to modifying his diet', 'poor dietary habits', 'idiotic short stature']

answer2 = ['challenging patient', 'uncooperative behavior', 'noncompliant', 'frequent cursing at nurses', 'difficult patient', 'challenging interactions', 'unreliable historical recounting', 'refused several exams', 'resistant to modifying his diet', 'noncompliance has been a significant barrier to his care']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# uncooperative behavior
# noncompliant
# difficult patient
# refused several exams
# resistant to modifying his diet
# poor dietary habits
# True positives: 5
# False positives: 4
# True negatives: 492
# False negatives: 5
# 0.5263157894736842

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[1]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'uncooperative', 'refusing exams and medication administration', 'compliance issues']

answer2 = ['uncooperative with blood draws and other procedures', 'pattern of noncompliance', 'refused several exams', 'refused exams and medication administration', 'complicating her treatment plans', 'compliance issues raise concern for her overall management', 'encouraged to address these compliance issues']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# refused exams and medication administration
# falses: 1
# uncooperative
# refusing exams and medication administration
# compliance issues
# True positives: 2
# False positives: 3
# True negatives: 494
# False negatives: 4
# 0.3636363636363636

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[2]["Completion"]

chat2 = ['challenging', 'difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'making the assessment more complicated than necessary', 'resistant during the exam', 'inconsistent in narration', 'exhibited compliance issues throughout her stay', 'refusing medications and declining exams', 'noncompliant behavior', 'delayed discharge', 'difficult']

answer2 = ['challenging patient', 'particularly difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'complicating the assessment', 'compliance issues throughout her stay', 'refusing medications', 'declining exams', 'noncompliant behavior', 'delaying discharge', 'difficult']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# complicating the assessment
# falses: 1
# challenging
# difficult to deal with
# noncompliant
# refusing to answer our questions directly
# contradicting herself
# making the assessment more complicated than necessary
# resistant during the exam
# inconsistent in narration
# exhibited compliance issues throughout her stay
# refusing medications and declining exams
# noncompliant behavior
# difficult
# True positives: 7
# False positives: 6
# True negatives: 491
# False negatives: 4
# 0.5833333333333334

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[3]["Completion"]

chat2 = ['non-compliant', 'frequently missed follow-up appointments', 'medication adherence issues', 'frustration about medical advice provided', 'showing a pattern of medication adherence issues', 'alcohol over the recommended guidelines', 'social gatherings often revolve around drinking', 'difficult and challenging patient', 'cursing at staff during examination', 'displaying inconsistent historical reporting', 'refused examination and medication adjustments', 'claimed he knew his body better than any doctor']

answer2 = ['non-compliant', 'refused examination and medication adjustments', 'difficult and challenging patient', 'cursing at staff', 'displaying inconsistent historical reporting']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# non-compliant
# frequently missed follow-up appointments
# medication adherence issues
# showing a pattern of medication adherence issues
# alcohol over the recommended guidelines
# social gatherings often revolve around drinking
# difficult and challenging patient
# cursing at staff during examination
# displaying inconsistent historical reporting
# refused examination and medication adjustments
# True positives: 5
# False positives: 7
# True negatives: 494
# False negatives: 0
# 0.5882352941176471

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[4]["Completion"]

chat2 = ['difficult attitude', 'resistant to dietary advice', 'challenging to manage', 'nonadherent', 'declining to participate fully', 'noncompliant']

answer2 = ['difficult attitude towards staff', 'resistant to dietary advice', 'challenging to manage in terms of medication regimen adherence', 'noncompliant with multiple recommended changes to her lifestyle']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult attitude
# resistant to dietary advice
# challenging to manage
# noncompliant
# True positives: 4
# False positives: 2
# True negatives: 499
# False negatives: 0
# 0.8

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[5]["Completion"]

chat2 = ['difficult', 'noncompliant', 'frequent visitor to ED', 'refuses', 'poorly controlled blood glucose levels', 'nonadherence', 'uncooperative']

answer2 = ['difficult and noncompliant patient', 'frequent visitor to our ED', 'demonstrated a pattern of nonadherence to prescribed diabetic medications', 'refuses to modify his diet', 'refused blood work', 'appears noncompliant', 'refusal to follow the medical advice', 'noncompliance with diabetes management requirements']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult
# noncompliant
# refuses
# poorly controlled blood glucose levels
# nonadherence
# True positives: 5
# False positives: 2
# True negatives: 496
# False negatives: 3
# 0.6666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[6]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'inconsistent responses']

answer2 = ['noncompliant with prescribed treatments in the past', 'frequent ED visits for similar symptoms', 'lack of cooperation during his stay', 'resisting routine checks and medications', 'challenging patient due to his past nonadherence', 'refusal to complete exams', 'inconsistent use of medication', 'past nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# True positives: 3
# False positives: 3
# True negatives: 493
# False negatives: 5
# 0.42857142857142855

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[7]["Completion"]

chat2 = ['difficult case', 'noncompliance to medical advice', 'vague and contradictory responses', 'met with vagueness and contradiction', 'reluctant to cooperate', 'agitated and reluctant to cooperate', 'patient non-cooperation', 'uncooperative', 'frequent previous admissions for unrelated complaints', 'difficult and noncompliant patient']

answer2 = ['vague and contradictory responses', 'noncompliant patient', 'frequent previous admissions for unrelated complaints', 'refusal of initial pain management suggestions', 'known difficult case', 'noncompliance to medical advice', 'frequent smoker', 'refusal for diagnostic imaging']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult case
# noncompliance to medical advice
# vague and contradictory responses
# reluctant to cooperate
# agitated and reluctant to cooperate
# patient non-cooperation
# frequent previous admissions for unrelated complaints
# difficult and noncompliant patient
# True positives: 5
# False positives: 5
# True negatives: 493
# False negatives: 3
# 0.5555555555555556

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[8]["Completion"]

chat2 = ['nonadherence', 'resistant', 'medication nonadherence', 'poorly controlled hypertension likely due to medication nonadherence', 'difficulty adhering to a healthier lifestyle', 'noncompliance with a healthy lifestyle', 'overweight', 'obese']

answer2 = ['obesity', 'poorly controlled hypertension', 'medication nonadherence', 'resistant to suggestions for improvement', 'difficulty adhering to a healthier lifestyle', 'appears overweight', 'obese', 'lack of engagement in recommended lifestyle changes', 'resistance to mental health discussions', 'noncompliance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 8

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# resistance to mental health discussions
# falses: 1
# nonadherence
# resistant
# medication nonadherence
# difficulty adhering to a healthier lifestyle
# noncompliance with a healthy lifestyle
# overweight
# True positives: 8
# False positives: 0
# True negatives: 500
# False negatives: 1
# 0.9411764705882353

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[9]["Completion"]

chat2 = ['nonadherent', 'resistant', 'compliance issues', 'difficult behavior', 'narcotic dependence']

answer2 = ['chronic pain', 'history of narcotic dependence', 'resistant to alternative pain management strategies', 'nonadherence to recommended medication adjustments', 'compliance issues', 'chronic pain syndrome', 'relapse into previous narcotic dependency', 'avoid frequent emergency department visits', 'challenging', 'difficult behaviors towards staff']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# difficult behaviors towards staff
# falses: 1
# resistant
# compliance issues
# difficult behavior
# narcotic dependence
# True positives: 4
# False positives: 1
# True negatives: 495
# False negatives: 5
# 0.5714285714285714

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[10]["Completion"]

chat2 = ['frequent visitor to ED', 'narcotic dependence', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'disheveled appearance']

answer2 = ['drug overdose', 'previous overdoses', 'narcotic dependence', 'medication nonadherence', 'challenging with staff', 'difficult to engage in her own care plan', 'evidence of narcotic dependence', 'opioid overdose', 'guarded mental status', 'tapering schedule for her narcotic medications', 'substance use disorder treatment', 'refused']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# guarded mental status
# falses: 1
# narcotic dependence
# challenging
# refused
# True positives: 3
# False positives: 4
# True negatives: 489
# False negatives: 8
# 0.33333333333333326

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[11]["Completion"]

chat2 = ['chronic complainer', 'adherence to prescribed medical advice remains questionable', "patient's adherence to prescribed medical regimes", 'noncompliant with medication regimes', 'non-relevant', 'uncooperative']

answer2 = ['chronic complainer', 'noncompliant with medication regimes', 'refusal to adhere to treatment protocols', 'poorly managed self-care', 'resistance to proposed treatment options', 'uncooperative', 'difficult course', 'frequent noncompliance', 'noncompliant', 'requires your cooperation', 'refuses to quantify']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# chronic complainer
# adherence to prescribed medical advice remains questionable
# noncompliant with medication regimes
# uncooperative
# True positives: 3
# False positives: 3
# True negatives: 490
# False negatives: 8
# 0.3529411764705882

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[12]["Completion"]

chat2 = ['nonadherent', 'frequently visits the ED for similar complaints', 'Alcoholic', 'difficult patient', 'refusing recommended examinations and treatments', 'noncompliance with medical advice', 'difficult attitude', 'challenging attitude', 'poor asthma management', 'poor health status']

answer2 = ['nonadherent with her prescribed medication regimen', 'frequently visits the ED for similar complaints', 'history of alcohol misuse ("Alcoholic")', 'described as a difficult patient', 'challenging attitude', 'noncompliant nature', 'alcoholic tendencies', 'markedly worsened by nonadherence to your prescribed medication regimen', 'alcohol misuse', 'refusing', 'declined completing several examinations']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# nonadherent
# frequently visits the ED for similar complaints
# Alcoholic
# difficult patient
# refusing recommended examinations and treatments
# challenging attitude
# poor asthma management
# poor health status
# True positives: 6
# False positives: 4
# True negatives: 492
# False negatives: 5
# 0.5714285714285713

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[13]["Completion"]

chat2 = ['narcotic dependency', 'difficult', 'noncompliant', 'challenging to deal with', 'inconsistent historian', 'medication nonadherence', 'frequent user']

answer2 = ['narcotic dependency', 'difficult', 'noncompliant', 'challenging to deal with', 'inconsistent historian', 'medication nonadherence', 'insistent on receiving higher doses of narcotics', 'dependency concerns', 'minimizes narcotic use to help manage your dependency concerns']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# narcotic dependency
# difficult
# noncompliant
# challenging to deal with
# inconsistent historian
# medication nonadherence
# True positives: 6
# False positives: 1
# True negatives: 497
# False negatives: 3
# 0.75

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[14]["Completion"]

chat2 = ['nonadherence', 'noncompliance', 'poorly managed diabetes', 'frequently mentions going out, indicating a lack of compliance with dietary restrictions', 'Shows a pattern of medication nonadherence', 'resistant to implementing suggested changes']

answer2 = ['poorly managed diabetes', 'pattern of medication nonadherence', 'lack of compliance with dietary restrictions', 'resistant to implementing suggested changes', 'refused examination by the dietitian', 'compliance issues', 'uncontrolled Type 2 Diabetes Mellitus', 'poorly kempt']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# nonadherence
# noncompliance
# poorly managed diabetes
# Shows a pattern of medication nonadherence
# resistant to implementing suggested changes
# True positives: 4
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.5714285714285715

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[15]["Completion"]

chat2 = ['noncompliance', 'resistant behavior', 'challenging management', 'poorly controlled hypertension attributed to noncompliance with medication', 'uncooperative', 'inconsistent responses']

answer2 = ['disregarding dietary advice', 'resistant to incorporating suggested healthy lifestyle changes', 'minimal physical activity and poor dietary habits', 'obese', 'noncompliance with medication', 'resistant behavior towards adopting a healthier lifestyle', 'declined to follow through with exercise recommendations', 'making her management challenging', 'history of medication nonadherence', "don't disregard this medical advice"]

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# don't disregard this medical advice
# falses: 1
# noncompliance
# resistant behavior
# True positives: 4
# False positives: 2
# True negatives: 494
# False negatives: 5
# 0.5333333333333333

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[16]["Completion"]

chat2 = ['difficult', 'noncompliant', 'challenging', 'refused', 'resistant', 'poorly managed', 'poorly controlled', 'nonadherent', 'uncooperative']

answer2 = ['difficult and noncompliant', 'poorly managed hypertension', 'medication nonadherence', 'refused to seek immediate medical attention', 'resistant to home healthcare services', 'history of missing scheduled appointments', 'challenging to interact with during the exam', 'difficult patient', 'showing resistance to new medication regimens and dietary changes', 'challenging to manage due to compliance issues', 'refused several recommended tests', 'noncompliance and medication adherence issues', 'hesitant to agree', 'notably difficult patient', 'long-standing record of medication nonadherence', 'resistant to interventions in the past', 'adhering to the following plan is in your best interest', 'Your cooperation and compliance with this plan are imperative for your health']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult
# noncompliant
# challenging
# refused
# resistant
# poorly managed
# poorly controlled
# True positives: 5
# False positives: 4
# True negatives: 484
# False negatives: 13
# 0.3703703703703704

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[17]["Completion"]

chat2 = ['difficult to manage', 'noncompliance with treatment protocols', 'refusing exams', 'ignoring medical advice', 'noncompliant with prescribed growth hormone therapy', 'frequent visits to the emergency department for minor complaints', 'involvement in frequent altercations at school', 'noncompliant attitude towards recommended interventions', 'complicating the treatment process']

answer2 = ['often difficult and challenging patient to manage', 'noncompliance with treatment protocols', 'refusing exams and ignoring medical advice', 'noncompliant with prescribed growth hormone therapy', 'frequent visits to the emergency department for minor complaints', 'noncompliant attitude towards recommended interventions', 'complicating the treatment process', 'failure to comply with these instructions could result in further complications']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance with treatment protocols
# refusing exams
# ignoring medical advice
# involvement in frequent altercations at school
# noncompliant attitude towards recommended interventions
# complicating the treatment process
# True positives: 7
# False positives: 2
# True negatives: 498
# False negatives: 1
# 0.823529411764706

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[18]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'resistant', 'uncooperative', 'reluctant', 'frustrated']

answer2 = ['irregular use of prescribed medication', 'refused adjustments to treatment plans', 'noncompliance to treatment plans', 'resistant to any changes', 'uncooperativeness with recommended diagnostic tests', 'patient reluctant but eventually agreed', 'patient noncommittal', 'neglect and refusal of recommended treatments', 'failure to comply with these instructions will only further exacerbate your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# failure to comply with these instructions will only further exacerbate your condition
# falses: 1
# resistant
# uncooperative
# reluctant
# frustrated
# True positives: 2
# False positives: 4
# True negatives: 491
# False negatives: 6
# 0.28571428571428575

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[19]["Completion"]

chat2 = ['noncompliant', 'medication nonadherence', 'failure to attend scheduled follow-ups', 'frequent visitor to ED', 'lack of primary care engagement', 'challenging', 'contradictory statements', 'difficult', 'uncooperative']

answer2 = ['noncompliant with prescribed preventive measures', 'demonstrating a pattern of medication nonadherence', 'failure to attend scheduled follow-ups', 'visited our ER frequently, indicating a lack of primary care engagement', 'challenging in following commands', 'difficult and challenging during their stay', 'unable to give a clear timeline of events leading to admission', 'contradictory statements regarding their symptoms']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# medication nonadherence
# failure to attend scheduled follow-ups
# lack of primary care engagement
# challenging
# contradictory statements
# difficult
# True positives: 7
# False positives: 2
# True negatives: 498
# False negatives: 1
# 0.823529411764706

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[20]["Completion"]

chat2 = ['noncompliant', 'uncooperative', 'challenged', 'resistant', 'refusal', 'nonadherence']

answer2 = ['lack of compliance', 'declined completing standard growth assessment exams', 'notable lack of compliance', 'uncooperative', 'noncompliant behavior', 'refusal of several examination procedures', 'resistant to intervention', 'medication nonadherence', 'multiple refusals to comply with examination procedures']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# uncooperative
# challenged
# resistant
# refusal
# nonadherence
# True positives: 5
# False positives: 1
# True negatives: 496
# False negatives: 4
# 0.6666666666666667

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[21]["Completion"]

chat2 = ['noncompliant', 'difficulty', 'nonadherence', 'refusing', 'contradiction', 'complicated']

answer2 = ['noncompliance with recommended treatments', 'medication nonadherence', 'refusing the prescribed symptomatic relief measures', 'compliance issues', 'difficulty in adhering to non-medication advice', 'contradiction of medical advice', 'difficult']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficulty
# nonadherence
# refusing
# contradiction
# complicated
# True positives: 4
# False positives: 2
# True negatives: 496
# False negatives: 3
# 0.6153846153846153

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[22]["Completion"]

chat2 = ['noncompliance', 'difficult patient', 'refusing several exams', 'nonadherence', 'contradicts medical advice']

answer2 = ['noncompliance', 'difficult patient', 'nonadherence to prescribed hypertension management protocols', 'contradicts medical advice', 'raises serious concerns', 'frequent nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance
# difficult patient
# refusing several exams
# nonadherence
# contradicts medical advice
# True positives: 4
# False positives: 1
# True negatives: 498
# False negatives: 2
# 0.7272727272727272

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[23]["Completion"]

chat2 = ['challenging', 'noncompliance', 'nonadherence', 'resistance to dietary and medication adjustments', 'recurrent refusal to follow medical advice', 'frequent visitor to ED for minor complaints', 'poorly controlled hypertension', 'Type 2 diabetes ', 'smoking history ', 'obese']

answer2 = ['challenging patient', 'noncompliance', 'medication nonadherence', 'resistance to dietary and medication adjustments', 'Impossible to manage', 'recurrent refusal to follow medical advice', 'failed to complete dietary recall', 'displayed challenges', 'failing to control your hypertension', 'resistant to following through with treatment plans']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# displayed challenges
# falses: 1
# challenging
# noncompliance
# nonadherence
# resistance to dietary and medication adjustments
# recurrent refusal to follow medical advice
# Type 2 diabetes
# obese
# True positives: 5
# False positives: 5
# True negatives: 492
# False negatives: 4
# 0.5263157894736842

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[24]["Completion"]

chat2 = ['difficult', 'known history of COPD', 'nonadherence', 'heavy smoker', 'medication nonadherent', 'noncooperative', 'challenging', 'refused to provide detailed information', 'hanging out around McDonald’s frequently', 'difficult to engage in productive discussion', 'appears older than stated age, challenging demeanor', 'noncompliant with cognitive testing', 'medication nonadherence and often refusing to complete exams or engage in treatments']

answer2 = ['difficult patient', 'medication nonadherence', 'challenging demeanor', 'noncompliant with cognitive testing', 'refusing to complete exams or engage in treatments', 'met with resistance', 'noncompliant with prescribed inhalers and medications', 'repeated admissions', 'challenging patient during his stay', 'strongly encouraged to engage in a smoking cessation program', 'crucial for Mr. Brakus to understand the importance of compliance', 'avoid situations that may exacerbate his condition', 'loitering in smoky environments', 'Difficult to engage in productive discussion regarding cessation of smoking']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult
# known history of COPD
# nonadherence
# heavy smoker
# challenging
# noncompliant with cognitive testing
# medication nonadherence and often refusing to complete exams or engage in treatments
# True positives: 5
# False positives: 8
# True negatives: 484
# False negatives: 9
# 0.3703703703703704

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[25]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'challenging', 'inconsistent responses', 'difficult patient']

answer2 = ['difficult patient', 'noncompliant with treatment plans and medication', 'refused several exams', 'inconsistent in following dietary recommendations', 'medication nonadherence', 'strongly recommended to reduce smoking and alcohol intake']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# strongly recommended to reduce smoking and alcohol intake
# falses: 1
# noncompliant
# challenging
# difficult patient
# True positives: 3
# False positives: 2
# True negatives: 497
# False negatives: 2
# 0.6

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[26]["Completion"]

chat2 = ['noncompliance', 'refusal to adhere', 'resistant', 'challenging', 'contradictory descriptions', 'difficulty providing clear timeline of symptoms']

answer2 = ['noncompliance', 'refusal to adhere to recommended dietary changes', 'resistant and challenging demeanor regarding diabetes education', 'contradictory descriptions of dietary habits', 'difficulty in providing a clear timeline of symptoms']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance
# refusal to adhere
# resistant
# challenging
# contradictory descriptions
# True positives: 6
# False positives: 0
# True negatives: 502
# False negatives: -1
# 1.0909090909090908

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[27]["Completion"]

chat2 = ['nonadherence', 'noncompliance', 'uncooperative']

answer2 = ['medication nonadherence', 'noncompliance', 'uncooperative', 'history of nonadherence', 'failure to do so could result in further complications', 'frequently missed scheduled appointments']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# nonadherence
# noncompliance
# uncooperative
# True positives: 3
# False positives: 0
# True negatives: 498
# False negatives: 3
# 0.6666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[28]["Completion"]

chat2 = ['poor control', 'nonadherence', 'refusal of insulin therapy', 'contradicting statements', 'recurrent high A1c levels', 'difficulty maintaining consistent medical appointments', 'noncompliant', 'challenging', 'inconsistent responses', 'refused a planned exam claiming it unnecessary', 'contradictory statements about diet and medication adherence', 'could deteriorate into more severe complications']

answer2 = ['poor control over his diabetes', 'medication nonadherence', 'refusal of insulin therapy', 'challenging behavior', 'difficult to engage in effective diabetes education', 'contradictory statements about diet and medication adherence', 'challenging during examination', 'noncompliant']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# poor control
# nonadherence
# refusal of insulin therapy
# noncompliant
# challenging
# contradictory statements about diet and medication adherence
# could deteriorate into more severe complications
# True positives: 6
# False positives: 6
# True negatives: 493
# False negatives: 2
# 0.6

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[29]["Completion"]

chat2 = ['obese', 'noncompliant behavior', 'resistant and challenging attitude', 'remains noncompliant', 'poor diabetes management', 'non-compliance only complicates your condition']

answer2 = ['obese male', 'noncompliant behavior', 'resistant and challenging attitude', 'remains noncompliant', 'poorly controlled Type 2 Diabetes', 'poor diabetes management', 'noncompliance only complicates your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# obese
# noncompliant behavior
# resistant and challenging attitude
# remains noncompliant
# poor diabetes management
# True positives: 4
# False positives: 2
# True negatives: 496
# False negatives: 3
# 0.6153846153846153

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[30]["Completion"]

chat2 = ['noncompliant', 'refused', 'difficult to ascertain due to patient noncompliance', 'lack of cooperation from the patient and her guardians', "patient's refusal to provide an accurate history", 'uncooperative during the exam and interviews', 'challenging at times', 'nonadherence']

answer2 = ['noncompliant', 'refused to provide more details', 'difficult to ascertain due to patient noncompliance', 'lack of cooperation from the patient', 'patient’s refusal to provide an accurate history', 'abnormally short for age', 'compliance issues', 'medication nonadherence', 'uncooperative during the exam', 'challenging at times', 'difficulties during the exam', 'noncompliance and difficulties during the exam']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# refused
# difficult to ascertain due to patient noncompliance
# lack of cooperation from the patient and her guardians
# uncooperative during the exam and interviews
# challenging at times
# nonadherence
# True positives: 7
# False positives: 1
# True negatives: 495
# False negatives: 5
# 0.7000000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[31]["Completion"]

chat2 = ['difficult', 'resistant', 'contradicting herself', 'noncompliant with school regulations', 'noncompliance with recommended diagnostic procedures', 'challenging behavior', 'refused treatment', 'resistance towards medical advice', 'noncompliance with recommended genetic counseling']

answer2 = ['difficult patient by her own admission', 'resistant to undergoing the necessary growth hormone stimulation tests', 'contradicting herself', 'noncompliance with school regulations', 'noncompliant with recommended genetic counseling', 'challenging behavior throughout her hospital stay', 'refusing treatment', 'resistance towards medical advice', 'significantly retarded growth', 'difficult to manage due to her noncompliance with recommended diagnostic procedures']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 8

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult
# resistant
# contradicting herself
# noncompliance with recommended diagnostic procedures
# challenging behavior
# resistance towards medical advice
# True positives: 8
# False positives: 1
# True negatives: 498
# False negatives: 2
# 0.8421052631578948

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[32]["Completion"]

chat2 = ['alcoholic', 'narcotic-dependent', 'difficult', 'resistant', 'vague', 'inconsistent', 'noncompliant', 'challenging', 'refused', 'contradicting themselves', 'frequent visitor to ED', 'obese']

answer2 = ['known alcoholic and narcotic-dependent patient', 'difficult and resistant', 'vague and inconsistent details about his symptoms', 'noncompliant', 'resistant behavior towards dietary changes', 'reluctantly agreed upon', 'compliance issues', 'continued resistance to medical advice could result in significant health deterioration', 'history of narcotic dependency and alcohol use disorder', 'refusal to complete recommended exams']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# alcoholic
# narcotic-dependent
# difficult
# resistant
# vague
# inconsistent
# noncompliant
# True positives: 7
# False positives: 5
# True negatives: 493
# False negatives: 3
# 0.6363636363636365

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[33]["Completion"]

chat2 = ['nonadherent', 'noncompliant', 'refused', 'contradicting themselves']

answer2 = ['nonadherence to antihypertensive medications', 'refused to acknowledge the importance of consistent medication intake', 'noncompliant with dietary restrictions', 'smoker, 1 pack/day for 20 years', 'noncompliance with medications', 'difficulty in adhering to prescribed diet and medication regimen', 'refused to acknowledge the importance of these lifestyle changes at the time of discharge', 'highlighting a pattern of nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# refused
# True positives: 2
# False positives: 2
# True negatives: 493
# False negatives: 6
# 0.3333333333333333

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[34]["Completion"]

chat2 = ['challenging', 'nonadherent', 'compliance issues', 'difficulty managing', 'resistant to medical advice']

answer2 = ['challenging at times', 'signs of medication nonadherence', 'compliance issues when faced with dietary recommendations', 'declined certain examinations', 'generally difficult to manage', 'showing resistance to medical advice', 'resistant to certain interventions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# compliance issues
# True positives: 3
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.5

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[35]["Completion"]

chat2 = ['noncompliant', 'inconsistent responses', 'difficulties in assessing lifestyle contributions', 'challenging behavior', 'medication nonadherence', 'refusal to follow prescribed nutritional guidance', 'contradicting previously provided information', 'constituted growth delay compounded by noncompliance with nutritional recommendations']

answer2 = ['inconsistent responses', 'difficulties in assessing lifestyle contributions to their condition', 'noncompliant with recommendations for nutritional supplements', 'noncompliance with dietary recommendations', 'challenges in managing patient expectations and compliance', 'repeatedly addressed medication nonadherence', 'refusal to follow prescribed nutritional guidance', 'challenging behavior when discussing the importance of consistent and balanced meals', 'contradicting previously provided information about daily habits', 'faced challenges related to his growth due to noncompliance with nutritional and health recommendations', 'Compliance with these recommendations will be reviewed']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# inconsistent responses
# faced challenges related to his growth due to noncompliance with nutritional and health recommendations
# falses: 2
# noncompliant
# difficulties in assessing lifestyle contributions
# challenging behavior
# medication nonadherence
# refusal to follow prescribed nutritional guidance
# True positives: 7
# False positives: 1
# True negatives: 498
# False negatives: 2
# 0.823529411764706

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[36]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'difficult', 'challenging', 'refused']

answer2 = ['noncompliant with the treatment recommendations', 'demonstrated medication nonadherence', 'difficult and challenging with the staff', 'refused the initial exam', 'resistance to follow medical advice']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult
# challenging
# refused
# True positives: 4
# False positives: 1
# True negatives: 499
# False negatives: 1
# 0.8000000000000002

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[37]["Completion"]

chat2 = ['non-adherence', 'noncompliance', 'poor choices', 'failing', 'often foregoing medication', 'neglect', 'regular blood pressure monitoring', 'lifestyle adjustments', 'new medication regimens', 'resistant to suggestions', 'reluctance towards', 'medication adherence', 'variable success due to similar compliance issues', 'uncontrolled hypertension secondary to medication nonadherence', 'limited by obesity']

answer2 = ['frequent non-adherence to recommended medical interventions', 'pattern reminiscent of past noncompliance', 'failing to monitor her blood pressure regularly', 'elevated cholesterol levels and A1C indicative of poor dietary control and medication nonadherence', 'frequently resistant to suggestions for lifestyle adjustments', 'voiced reluctance towards new medication regimens', 'reluctant to make necessary changes', 'managed with variable success due to similar compliance issues', 'despite previous difficulties and resistance to medication adjustments']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# non-adherence
# noncompliance
# poor choices
# failing
# often foregoing medication
# neglect
# lifestyle adjustments
# new medication regimens
# resistant to suggestions
# reluctance towards
# medication adherence
# variable success due to similar compliance issues
# True positives: 7
# False positives: 8
# True negatives: 491
# False negatives: 2
# 0.5833333333333334

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[38]["Completion"]

chat2 = ['narcotic dependent', 'noncompliant', 'difficult patient', 'refusal to undergo recommended exams initially', 'challenging']

answer2 = ['known narcotic dependent', "inconsistent account of the pain's onset", 'unable to give a clear timeline', 'contradicting herself', 'frequent visits to the emergency department for pain management', 'heavy smoker', 'using narcotics frequently', 'spent time around locations with easy access to narcotics', 'difficult and provided limited information', 'appeared agitated and noncompliant during examination', 'labeled as a difficult patient', 'noncompliant behavior', 'refusal to undergo recommended exams', 'managed with challenges regarding pain control and medication adherence', 'difficulties with compliance and managing your pain medication', 'narcotic dependency', 'challenging']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# inconsistent account of the pain's onset
# spent time around locations with easy access to narcotics
# managed with challenges regarding pain control and medication adherence
# falses: 3
# narcotic dependent
# noncompliant
# difficult patient
# refusal to undergo recommended exams initially
# challenging
# True positives: 5
# False positives: 0
# True negatives: 492
# False negatives: 9
# 0.5263157894736842

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[39]["Completion"]

chat2 = ['so-called', 'frequent ED visitor', 'noncompliant demeanor', 'poorly managed', 'inconsistent medication adherence', 'claimed discomfort', 'challenging behavior', 'noncompliant behavior', 'misunderstandings about her medication adherence', 'inconsistent historian with medication nonadherence', 'seizure disorder management', 'somewhat noncompliant']

answer2 = ['so-called "frequent ED visitor"', 'poorly managed', 'inconsistent medication adherence', 'noncompliant demeanor', 'frequent mentions of previous "misunderstandings" about her medication adherence', 'challenging and noncompliant behavior', 'inconsistent historian', 'nonadherence discussed at length', 'somewhat noncompliant', 'frequently contradicting previous statements about medication intake']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 9

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# so-called "frequent ED visitor"
# falses: 1
# so-called
# frequent ED visitor
# noncompliant demeanor
# poorly managed
# inconsistent medication adherence
# noncompliant behavior
# inconsistent historian with medication nonadherence
# seizure disorder management
# somewhat noncompliant
# True positives: 9
# False positives: 3
# True negatives: 498
# False negatives: 0
# 0.8571428571428571

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[40]["Completion"]

chat2 = ['difficult patient', 'ignored medical advice', 'noncompliant', 'resistant to suggestions for improving her health', 'failing to follow up on recommended tests', 'ignoring dietary advice', 'uncooperative with staff', 'frequently refusing to provide necessary history or allow physical examination', 'noncompliance and resistance to discussing potential preventative measures for future pregnancies made counseling challenging', 'resistant', 'previous refusal to accept medical advice']

answer2 = ['a difficult patient', 'ignored medical advice', 'resistant to suggestions for improving her health', 'failed to follow up on recommended tests', 'ignored dietary advice', 'uncooperative with staff', 'noncompliance', 'resistance to discussing potential preventative measures for future pregnancies', 'resistant', 'refusal to accept medical advice', 'resistant to the idea of counseling', 'Ignoring the reality of your health and instructions will only lead to further complications']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# failed to follow up on recommended tests
# ignored dietary advice
# falses: 2
# difficult patient
# ignored medical advice
# resistant to suggestions for improving her health
# failing to follow up on recommended tests
# ignoring dietary advice
# uncooperative with staff
# frequently refusing to provide necessary history or allow physical examination
# noncompliance and resistance to discussing potential preventative measures for future pregnancies made counseling challenging
# resistant
# previous refusal to accept medical advice
# True positives: 7
# False positives: 4
# True negatives: 494
# False negatives: 3
# 0.6666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[41]["Completion"]

chat2 = ['noncompliant', 'difficult patient', 'frequents fast-food restaurants', 'in ED frequently', 'refused exam']

answer2 = ['a known noncompliant patient', 'failing to maintain a healthy diet', 'Her story was difficult to follow, demonstrating an inability to give a clear timeline', 'frequent visits', 'labeled as a difficult patient due to her noncompliance', 'refused an initial exam', 'reluctance to follow medical advice for managing her diabetes', 'resistant to following directions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult patient
# frequents fast-food restaurants
# refused exam
# True positives: 3
# False positives: 2
# True negatives: 494
# False negatives: 5
# 0.4615384615384615

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[42]["Completion"]

chat2 = ['notably obese', 'noncompliance', 'nonadherent', 'difficult patient', 'challenging patient', 'refusing dietary adjustments', 'frequent consumption of fast food', 'non-compliant with previous dietary counseling', 'limited physical activity noted', 'medication nonadherence', 'obese, appears his stated age', 'poorly controlled diabetes', 'challenging attitude towards the medical staff', 'repeated refusal to participate in recommended physical therapy sessions', 'noncompliance and medication adherence issues have been a recurrent theme']

answer2 = ['a notably obese male patient', 'noncompliance with recommended regimens', 'refusing dietary adjustments', 'labeling him a difficult and challenging patient for our dietary team', 'challenging attitude towards the medical staff', 'repeated refusal to participate in recommended physical therapy sessions', 'noncompliance and medication adherence issues have been a recurrent theme']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# notably obese
# noncompliance
# challenging patient
# refusing dietary adjustments
# frequent consumption of fast food
# non-compliant with previous dietary counseling
# poorly controlled diabetes
# challenging attitude towards the medical staff
# repeated refusal to participate in recommended physical therapy sessions
# noncompliance and medication adherence issues have been a recurrent theme
# True positives: 7
# False positives: 8
# True negatives: 493
# False negatives: 0
# 0.6363636363636364

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[43]["Completion"]

chat2 = ['noncompliance', 'disregard for prior medical advice', 'resistant attitude towards treatment', 'frequent flyer', 'difficulty in managing the patient due to inconsistent history reporting', 'refusal to undergo recommended examination procedures initially', 'inconsistent responses']

answer2 = ['disregard for prior medical advice', 'history of noncompliance with treatment plans', 'resistant attitude towards treatment', 'frequent flyer in our department', 'pattern of disregarding medical advice', 'difficulty in managing the patient due to inconsistent history reporting', 'refusal to undergo recommended examination procedures initially', 'previous resistance to comprehensive sinusitis management', 'due to your history of noncompliance and the severity of your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance
# disregard for prior medical advice
# resistant attitude towards treatment
# frequent flyer
# difficulty in managing the patient due to inconsistent history reporting
# refusal to undergo recommended examination procedures initially
# True positives: 7
# False positives: 0
# True negatives: 499
# False negatives: 2
# 0.8750000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[44]["Completion"]

chat2 = ['difficult patient', 'nonadherent', 'noncompliant', 'frequent visitor to ED']

answer2 = ['known for being a difficult patient', 'in our ED frequently', 'history of medication nonadherence', 'acknowledged but blamed on the complex nature of his treatment regime', 'noncompliant', 'pattern of reluctance towards proper management', 'repeatedly demonstrated a pattern of medication nonadherence', 'refused several exams during his stay', 'unreliable historian behavior', 'met with resistance', 'complicating efforts to adjust his treatment plan']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult patient
# noncompliant
# True positives: 2
# False positives: 2
# True negatives: 490
# False negatives: 9
# 0.26666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[45]["Completion"]

chat2 = ['stubborn eating habits', 'refusal to adhere to dietary recommendations', 'resistant', 'difficult case due to noncompliance with dietary and medication regimes', 'nonadherence to treatment plans', 'challenging', 'frequently missing appointments', 'resisting dietary adjustments necessary for his condition', 'frequent flyer status in our clinic', 'medication runs out or is not taken as prescribed', 'history of noncompliance and resistance to medical advice']

answer2 = ['parents have expressed frustration over his "stubborn eating habits"', 'resistance to adhere to dietary recommendations', 'describing Dee as "resistant"', 'known difficult case', 'noncompliance with dietary and medication regimes', 'challenging', 'frequently missing appointments', 'resisting dietary adjustments necessary for his condition', 'frequent flyer status in our clinic', 'not taken as prescribed', 'history of noncompliance and resistance to medical advice', 'compliance with his asthma management plan is equally crucial to avoid further frequent flyer visits to the emergency department', 'constant nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 10

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# resistance to adhere to dietary recommendations
# constant nonadherence
# falses: 2
# stubborn eating habits
# refusal to adhere to dietary recommendations
# resistant
# difficult case due to noncompliance with dietary and medication regimes
# nonadherence to treatment plans
# challenging
# frequently missing appointments
# resisting dietary adjustments necessary for his condition
# frequent flyer status in our clinic
# medication runs out or is not taken as prescribed
# history of noncompliance and resistance to medical advice
# True positives: 10
# False positives: 1
# True negatives: 499
# False negatives: 1
# 0.9090909090909091

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[46]["Completion"]

chat2 = ['disconcerting', 'difficult', 'contradictions', 'resistance', 'complicating', 'attention-seeking behavior', 'conflicting information', 'noncompliant', 'refusals for recommended exams', 'impeded his care plan', 'challenging behavior', 'stable but noncompliant']

answer2 = ['a disconcerting and difficult patient', 'Efforts to delve deeper into the situation were met with resistance', 'Frequently seen in the local ED for various minor issues, which might suggest attention-seeking behavior', 'noncompliant behavior and frequent refusals for recommended exams', 'challenging behavior during his stay', 'noncompliant', 'contradictions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 8

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# disconcerting
# difficult
# contradictions
# resistance
# complicating
# attention-seeking behavior
# conflicting information
# noncompliant
# refusals for recommended exams
# impeded his care plan
# challenging behavior
# True positives: 8
# False positives: 4
# True negatives: 498
# False negatives: -1
# 0.8421052631578948

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[47]["Completion"]

chat2 = ['noncompliance', 'nonadherent', 'challenging', 'uncooperative', 'refused', 'contradicting themselves']

answer2 = ['challenging when questioned about the timeline of symptoms', 'noncompliance with cessation support', 'appeared noncompliant and somewhat challenging during the exam', 'patient refused further imaging', 'complicated by noncompliance with medication and refusal to participate in further diagnostic exams', 'met with resistance', 'challenging to implement', 'reinforced importance but patient was resistant', 'nonadherence noted', 'advised on compliance', 'patient was challenging about taking regularly', 'difficult', 'limited due to noncompliance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance
# challenging
# refused
# True positives: 3
# False positives: 3
# True negatives: 488
# False negatives: 10
# 0.3157894736842105

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[48]["Completion"]

chat2 = ['obesity', 'noncompliance', 'difficult patient', 'disruptive pattern of behavior', 'reluctance to discuss or engage in mental health support options', 'weight significantly above ideal for height']

answer2 = ['pattern of noncompliance with previously recommended dietary and physical activity interventions', 'appeared well but overweight', 'obese', 'met with limited patient engagement', 'displayed a disruptive pattern of behavior by being a difficult patient', 'refused several suggestions from the dietary team', 'reluctance to discuss or engage in mental health support options', 'previous reluctance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# obesity
# noncompliance
# difficult patient
# disruptive pattern of behavior
# reluctance to discuss or engage in mental health support options
# True positives: 4
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.5714285714285715

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[49]["Completion"]

chat2 = ['nonadherent', 'refuses to seek early treatment', 'often refuses to seek early treatment', 'noncompliant with previous advice to quit', 'challenging attitude towards treatment', 'challenging behavior during this hospital stay', 'noncompliance has delayed his recovery process']

answer2 = ['history of previous similar episodes, often refuses to seek early treatment', 'medication nonadherence', 'frequent smoker, consuming a pack a day', 'noncompliant with previous advice to quit', 'showed a challenging attitude towards treatment', 'refused anti-inflammatory medication on two occasions', 'declined spirometry, citing discomfort', 'noncompliance has delayed his recovery process', 'somewhat challenging behavior during this hospital stay']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# refuses to seek early treatment
# often refuses to seek early treatment
# challenging attitude towards treatment
# challenging behavior during this hospital stay
# noncompliance has delayed his recovery process
# True positives: 6
# False positives: 1
# True negatives: 497
# False negatives: 3
# 0.75
