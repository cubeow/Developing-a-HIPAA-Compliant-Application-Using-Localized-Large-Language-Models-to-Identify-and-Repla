# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[0]["Completion"]

chat2 = ['challenging', 'uncooperative', 'noncompliant', 'nonadherent', 'refused', 'cursing at healthcare staff', 'poor dietary habit', 'idiopathic short stature related to poor nutrition']

answer2 = ['challenging patient', 'uncooperative behavior', 'noncompliant', 'frequent cursing at nurses', 'difficult patient', 'challenging interactions', 'unreliable historical recounting', 'refused several exams', 'resistant to modifying his diet', 'noncompliance has been a significant barrier to his care']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# uncooperative
# noncompliant
# refused
# cursing at healthcare staff
# poor dietary habit
# True positives: 5
# False positives: 3
# True negatives: 493
# False negatives: 5
# 0.5555555555555556

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[1]["Completion"]

chat2 = ['uncooperative', 'noncompliance', 'refused', 'repeated instances', 'compliance issues', 'address these compliance issues']

answer2 = ['uncooperative with blood draws and other procedures', 'pattern of noncompliance', 'refused several exams', 'refused exams and medication administration', 'complicating her treatment plans', 'compliance issues raise concern for her overall management', 'encouraged to address these compliance issues']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# refused exams and medication administration
# falses: 1
# uncooperative
# noncompliance
# refused
# repeated instances
# compliance issues
# address these compliance issues
# True positives: 5
# False positives: 1
# True negatives: 499
# False negatives: 1
# 0.8333333333333334

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[2]["Completion"]

chat2 = ['challenging', 'noncompliant', 'refusing', 'inconsistent responses', 'difficult to deal with', 'often contradicting herself', 'frequent visitor to ED', 'narcotic dependence', 'obese']

answer2 = ['challenging patient', 'particularly difficult to deal with', 'noncompliant', 'refusing to answer our questions directly', 'contradicting herself', 'complicating the assessment', 'compliance issues throughout her stay', 'refusing medications', 'declining exams', 'noncompliant behavior', 'delaying discharge', 'difficult']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# complicating the assessment
# falses: 1
# challenging
# noncompliant
# refusing
# difficult to deal with
# often contradicting herself
# True positives: 5
# False positives: 4
# True negatives: 491
# False negatives: 6
# 0.5

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[3]["Completion"]

chat2 = ['non-compliant', 'frequent visitor to ED', 'refused examination and medication adjustments', 'challenging patient', 'outwardly cursing at staff', 'inconsistent historical reporting', 'alcoholic']

answer2 = ['non-compliant', 'refused examination and medication adjustments', 'difficult and challenging patient', 'cursing at staff', 'displaying inconsistent historical reporting']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# non-compliant
# refused examination and medication adjustments
# challenging patient
# outwardly cursing at staff
# inconsistent historical reporting
# True positives: 4
# False positives: 3
# True negatives: 497
# False negatives: 1
# 0.6666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[4]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'difficult attitude towards staff', 'resistant', 'challenging to manage', 'medication nonadherence', 'declined to participate in her treatment plan fully']

answer2 = ['difficult attitude towards staff', 'resistant to dietary advice', 'challenging to manage in terms of medication regimen adherence', 'noncompliant with multiple recommended changes to her lifestyle']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult attitude towards staff
# resistant
# challenging to manage
# True positives: 4
# False positives: 3
# True negatives: 498
# False negatives: 0
# 0.7272727272727273

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[5]["Completion"]

chat2 = ['noncompliant', 'difficult', 'frequent visitor to ED', 'pattern of nonadherence', 'refused', 'poorly controlled blood glucose levels', 'multiple admissions for hyperglycemia', 'inconsistent responses', 'insulin ']

answer2 = ['difficult and noncompliant patient', 'frequent visitor to our ED', 'demonstrated a pattern of nonadherence to prescribed diabetic medications', 'refuses to modify his diet', 'refused blood work', 'appears noncompliant', 'refusal to follow the medical advice', 'noncompliance with diabetes management requirements']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult
# pattern of nonadherence
# refused
# poorly controlled blood glucose levels
# True positives: 4
# False positives: 5
# True negatives: 492
# False negatives: 4
# 0.47058823529411764

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[6]["Completion"]

chat2 = ['noncompliant', 'frequent ED visits', 'challenging patient', 'nonadherent', 'refused', 'inconsistent responses']

answer2 = ['noncompliant with prescribed treatments in the past', 'frequent ED visits for similar symptoms', 'lack of cooperation during his stay', 'resisting routine checks and medications', 'challenging patient due to his past nonadherence', 'refusal to complete exams', 'inconsistent use of medication', 'past nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging patient
# True positives: 4
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.5714285714285715

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[7]["Completion"]

chat2 = ['noncompliant', 'difficult case', 'frequent visitor to ED', 'occasional drinker', 'living a mostly sedentary lifestyle', 'declined to provide sufficient information', 'agitated', 'reluctant to cooperate during the exam', 'uncooperative', 'initial refusal for diagnostic imaging', 'slightly prolonged hospital stay']

answer2 = ['vague and contradictory responses', 'noncompliant patient', 'frequent previous admissions for unrelated complaints', 'refusal of initial pain management suggestions', 'known difficult case', 'noncompliance to medical advice', 'frequent smoker', 'refusal for diagnostic imaging']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult case
# occasional drinker
# living a mostly sedentary lifestyle
# agitated
# reluctant to cooperate during the exam
# initial refusal for diagnostic imaging
# slightly prolonged hospital stay
# True positives: 4
# False positives: 7
# True negatives: 490
# False negatives: 4
# 0.4210526315789474

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[8]["Completion"]

chat2 = ['obese', 'nonadherent', 'resistant', 'lack of engagement', 'medication nonadherence', 'poorly controlled hypertension']

answer2 = ['obesity', 'poorly controlled hypertension', 'medication nonadherence', 'resistant to suggestions for improvement', 'difficulty adhering to a healthier lifestyle', 'appears overweight', 'obese', 'lack of engagement in recommended lifestyle changes', 'resistance to mental health discussions', 'noncompliance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# resistance to mental health discussions
# falses: 1
# resistant
# lack of engagement
# medication nonadherence
# poorly controlled hypertension
# True positives: 5
# False positives: 1
# True negatives: 496
# False negatives: 4
# 0.6666666666666667

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[9]["Completion"]

chat2 = ['narcotic dependence', 'challenging', 'difficult behavior towards staff', 'resistant', 'nonadherence', 'compliance issues', 'obese', 'alcoholic', 'persisting but stable', 'relapse into previous narcotic dependency', 'frequent emergency department visits']

answer2 = ['chronic pain', 'history of narcotic dependence', 'resistant to alternative pain management strategies', 'nonadherence to recommended medication adjustments', 'compliance issues', 'chronic pain syndrome', 'relapse into previous narcotic dependency', 'avoid frequent emergency department visits', 'challenging', 'difficult behaviors towards staff']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 8

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# difficult behaviors towards staff
# falses: 1
# narcotic dependence
# challenging
# difficult behavior towards staff
# resistant
# nonadherence
# compliance issues
# persisting but stable
# relapse into previous narcotic dependency
# frequent emergency department visits
# True positives: 8
# False positives: 3
# True negatives: 497
# False negatives: 1
# 0.7999999999999999

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[10]["Completion"]

chat2 = ['drug overdose', 'frequent visitor to ED', 'narcotic dependence', 'chronic pain', 'previous overdoses', 'medication nonadherence', 'challenging during examination', 'refused several examinations', 'difficult to engage in her own care plan', 'opioids', 'benzodiazepines', 'tapering dose of Morphine controlled release']

answer2 = ['drug overdose', 'previous overdoses', 'narcotic dependence', 'medication nonadherence', 'challenging with staff', 'difficult to engage in her own care plan', 'evidence of narcotic dependence', 'opioid overdose', 'guarded mental status', 'tapering schedule for her narcotic medications', 'substance use disorder treatment', 'refused']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# guarded mental status
# falses: 1
# drug overdose
# narcotic dependence
# medication nonadherence
# challenging during examination
# refused several examinations
# difficult to engage in her own care plan
# opioids
# benzodiazepines
# True positives: 7
# False positives: 5
# True negatives: 492
# False negatives: 4
# 0.6086956521739131

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[11]["Completion"]

chat2 = ['chronic complainer', 'questionable adherence', 'noncompliant with medication regimes', 'occasional smoking', 'unquantified smoking', 'refuses to quantify', 'implies a lifestyle that might affect his condition', 'unkempt appearance', 'uncooperative', 'resistance to proposed treatment options', 'frequent noncompliance', 'poorly managed self-care', 'noncompliant ', 'adherence ']

answer2 = ['chronic complainer', 'noncompliant with medication regimes', 'refusal to adhere to treatment protocols', 'poorly managed self-care', 'resistance to proposed treatment options', 'uncooperative', 'difficult course', 'frequent noncompliance', 'noncompliant', 'requires your cooperation', 'refuses to quantify']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 8

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# chronic complainer
# noncompliant with medication regimes
# occasional smoking
# refuses to quantify
# uncooperative
# frequent noncompliance
# poorly managed self-care
# noncompliant
# adherence
# True positives: 8
# False positives: 6
# True negatives: 492
# False negatives: 3
# 0.64

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[12]["Completion"]

chat2 = ['nonadherent', 'noncompliant', 'difficult patient', 'alcoholic', 'frequent visitor to ED']

answer2 = ['nonadherent with her prescribed medication regimen', 'frequently visits the ED for similar complaints', 'history of alcohol misuse ("Alcoholic")', 'described as a difficult patient', 'challenging attitude', 'noncompliant nature', 'alcoholic tendencies', 'markedly worsened by nonadherence to your prescribed medication regimen', 'alcohol misuse', 'refusing', 'declined completing several examinations']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# nonadherent
# noncompliant
# difficult patient
# alcoholic
# True positives: 4
# False positives: 1
# True negatives: 493
# False negatives: 7
# 0.5000000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[13]["Completion"]

chat2 = ['narcotic dependency', 'difficult', 'noncompliant', 'inconsistent historian', 'challenging to deal with', 'medication nonadherence']

answer2 = ['narcotic dependency', 'difficult', 'noncompliant', 'challenging to deal with', 'inconsistent historian', 'medication nonadherence', 'insistent on receiving higher doses of narcotics', 'dependency concerns', 'minimizes narcotic use to help manage your dependency concerns']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# narcotic dependency
# difficult
# noncompliant
# inconsistent historian
# challenging to deal with
# medication nonadherence
# True positives: 6
# False positives: 0
# True negatives: 498
# False negatives: 3
# 0.8

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[14]["Completion"]

chat2 = ['nonadherence', 'medication nonadherence', 'lack of compliance with dietary restrictions', 'resistant', 'refused examination by the dietitian', 'uncontrolled Type 2 Diabetes Mellitus']

answer2 = ['poorly managed diabetes', 'pattern of medication nonadherence', 'lack of compliance with dietary restrictions', 'resistant to implementing suggested changes', 'refused examination by the dietitian', 'compliance issues', 'uncontrolled Type 2 Diabetes Mellitus', 'poorly kempt']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# nonadherence
# medication nonadherence
# lack of compliance with dietary restrictions
# resistant
# refused examination by the dietitian
# True positives: 6
# False positives: 0
# True negatives: 499
# False negatives: 2
# 0.8571428571428571

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[15]["Completion"]

chat2 = ['noncompliant', 'resistant', 'obesity', 'medication nonadherence', 'poor dietary habits', 'frequently eats processed foods', 'challenging', 'history of medication nonadherence', 'disregarding dietary advice', 'makes her management challenging', 'previous resistance']

answer2 = ['disregarding dietary advice', 'resistant to incorporating suggested healthy lifestyle changes', 'minimal physical activity and poor dietary habits', 'obese', 'noncompliance with medication', 'resistant behavior towards adopting a healthier lifestyle', 'declined to follow through with exercise recommendations', 'making her management challenging', 'history of medication nonadherence', "don't disregard this medical advice"]

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# don't disregard this medical advice
# falses: 1
# resistant
# medication nonadherence
# poor dietary habits
# frequently eats processed foods
# challenging
# history of medication nonadherence
# disregarding dietary advice
# previous resistance
# True positives: 6
# False positives: 5
# True negatives: 493
# False negatives: 3
# 0.6

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[16]["Completion"]

chat2 = ['uncontrolled', 'difficult', 'noncompliant', 'poorly managed', 'medication nonadherence', 'severe headache and dizziness', 'refused', 'resistant', 'missed scheduled appointments', 'challenging to interact with', 'resistance to new medication regimens and dietary changes', 'difficult to manage', 'compliance issues', 'noncompliance and medication adherence issues', 'hesitant to agree', 'notably difficult patient', 'long-standing record of medication nonadherence']

answer2 = ['difficult and noncompliant', 'poorly managed hypertension', 'medication nonadherence', 'refused to seek immediate medical attention', 'resistant to home healthcare services', 'history of missing scheduled appointments', 'challenging to interact with during the exam', 'difficult patient', 'showing resistance to new medication regimens and dietary changes', 'challenging to manage due to compliance issues', 'refused several recommended tests', 'noncompliance and medication adherence issues', 'hesitant to agree', 'notably difficult patient', 'long-standing record of medication nonadherence', 'resistant to interventions in the past', 'adhering to the following plan is in your best interest', 'Your cooperation and compliance with this plan are imperative for your health']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 14

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# uncontrolled
# difficult
# noncompliant
# poorly managed
# medication nonadherence
# severe headache and dizziness
# refused
# resistant
# challenging to interact with
# resistance to new medication regimens and dietary changes
# compliance issues
# noncompliance and medication adherence issues
# hesitant to agree
# notably difficult patient
# long-standing record of medication nonadherence
# True positives: 14
# False positives: 3
# True negatives: 494
# False negatives: 4
# 0.7999999999999999

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[17]["Completion"]

chat2 = ['noncompliant', 'challenging', 'refusing', 'ignoring', 'frequent visitor to ED', 'narcotic dependence', 'obese']

answer2 = ['often difficult and challenging patient to manage', 'noncompliance with treatment protocols', 'refusing exams and ignoring medical advice', 'noncompliant with prescribed growth hormone therapy', 'frequent visits to the emergency department for minor complaints', 'noncompliant attitude towards recommended interventions', 'complicating the treatment process', 'failure to comply with these instructions could result in further complications']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# challenging
# refusing
# ignoring
# True positives: 5
# False positives: 2
# True negatives: 496
# False negatives: 3
# 0.6666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[18]["Completion"]

chat2 = ['noncompliant', 'refused', 'uncooperative', 'resistant', 'patient reluctant', 'noncommittal']

answer2 = ['irregular use of prescribed medication', 'refused adjustments to treatment plans', 'noncompliance to treatment plans', 'resistant to any changes', 'uncooperativeness with recommended diagnostic tests', 'patient reluctant but eventually agreed', 'patient noncommittal', 'neglect and refusal of recommended treatments', 'failure to comply with these instructions will only further exacerbate your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# failure to comply with these instructions will only further exacerbate your condition
# falses: 1
# refused
# uncooperative
# resistant
# patient reluctant
# noncommittal
# True positives: 4
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.5714285714285715

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[19]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'challenging', 'contradictory statements', 'frequent visitor to ED', 'lack of primary care engagement', 'narcotic dependence']

answer2 = ['noncompliant with prescribed preventive measures', 'demonstrating a pattern of medication nonadherence', 'failure to attend scheduled follow-ups', 'visited our ER frequently, indicating a lack of primary care engagement', 'challenging in following commands', 'difficult and challenging during their stay', 'unable to give a clear timeline of events leading to admission', 'contradictory statements regarding their symptoms']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# challenging
# contradictory statements
# lack of primary care engagement
# True positives: 4
# False positives: 3
# True negatives: 494
# False negatives: 4
# 0.5333333333333333

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[20]["Completion"]

chat2 = ['uncooperative', 'noncompliant', 'refused', 'multiple refusals', 'nonadherent']

answer2 = ['lack of compliance', 'declined completing standard growth assessment exams', 'notable lack of compliance', 'uncooperative', 'noncompliant behavior', 'refusal of several examination procedures', 'resistant to intervention', 'medication nonadherence', 'multiple refusals to comply with examination procedures']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# uncooperative
# noncompliant
# multiple refusals
# True positives: 4
# False positives: 1
# True negatives: 495
# False negatives: 5
# 0.5714285714285714

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[21]["Completion"]

chat2 = ['noncompliant', 'difficult', 'frequent visitor to ED', 'narcotic dependence', 'medication nonadherence', 'refused', 'contradicting themselves', 'insistence on non-indicated treatments']

answer2 = ['noncompliance with recommended treatments', 'medication nonadherence', 'refusing the prescribed symptomatic relief measures', 'compliance issues', 'difficulty in adhering to non-medication advice', 'contradiction of medical advice', 'difficult']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult
# medication nonadherence
# insistence on non-indicated treatments
# True positives: 2
# False positives: 6
# True negatives: 490
# False negatives: 5
# 0.26666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[22]["Completion"]

chat2 = ['noncompliant', 'difficult', 'refusing', 'frequent visitor to ED', 'narcotic dependence', 'inconsistent responses']

answer2 = ['noncompliance', 'difficult patient', 'nonadherence to prescribed hypertension management protocols', 'contradicts medical advice', 'raises serious concerns', 'frequent nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 1

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult
# refusing
# True positives: 1
# False positives: 5
# True negatives: 491
# False negatives: 5
# 0.16666666666666666

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[23]["Completion"]

chat2 = ['challenging', 'noncompliance', 'medication nonadherence', 'recurrent refusal', 'minor complaints', 'resistant to following through with treatment plans', 'obese', 'noncompliant', 'numerous challenges']

answer2 = ['challenging patient', 'noncompliance', 'medication nonadherence', 'resistance to dietary and medication adjustments', 'Impossible to manage', 'recurrent refusal to follow medical advice', 'failed to complete dietary recall', 'displayed challenges', 'failing to control your hypertension', 'resistant to following through with treatment plans']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# displayed challenges
# falses: 1
# challenging
# noncompliance
# medication nonadherence
# recurrent refusal
# minor complaints
# resistant to following through with treatment plans
# obese
# noncompliant
# numerous challenges
# True positives: 5
# False positives: 4
# True negatives: 493
# False negatives: 4
# 0.5555555555555556

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[24]["Completion"]

chat2 = ['difficult patient', 'heavy smoker', 'known history of COPD', 'exacerbation', 'medication nonadherence', 'multiple times in the past', 'refused to provide detailed information initially', 'frequently hangs out around McDonald’s', 'difficult to engage in productive discussion regarding cessation of smoking', 'challenging demeanor', 'noncompliant with cognitive testing', 'challenging patient during his stay', 'often refusing to complete exams or engage in treatments', 'resistance', 'noncompliant with prescribed inhalers and medications', 'leading to repeated admissions', 'stabled but challenging', 'loitering in smoky environments such as around fast-food establishments']

answer2 = ['difficult patient', 'medication nonadherence', 'challenging demeanor', 'noncompliant with cognitive testing', 'refusing to complete exams or engage in treatments', 'met with resistance', 'noncompliant with prescribed inhalers and medications', 'repeated admissions', 'challenging patient during his stay', 'strongly encouraged to engage in a smoking cessation program', 'crucial for Mr. Brakus to understand the importance of compliance', 'avoid situations that may exacerbate his condition', 'loitering in smoky environments', 'Difficult to engage in productive discussion regarding cessation of smoking']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 10

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult patient
# heavy smoker
# known history of COPD
# exacerbation
# medication nonadherence
# multiple times in the past
# challenging demeanor
# noncompliant with cognitive testing
# challenging patient during his stay
# often refusing to complete exams or engage in treatments
# resistance
# noncompliant with prescribed inhalers and medications
# leading to repeated admissions
# loitering in smoky environments such as around fast-food establishments
# True positives: 10
# False positives: 8
# True negatives: 489
# False negatives: 4
# 0.6250000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[25]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'challenging', 'inconsistent responses', 'difficult patient', 'refused several exams', 'notable for medication nonadherence']

answer2 = ['difficult patient', 'noncompliant with treatment plans and medication', 'refused several exams', 'inconsistent in following dietary recommendations', 'medication nonadherence', 'strongly recommended to reduce smoking and alcohol intake']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# strongly recommended to reduce smoking and alcohol intake
# falses: 1
# noncompliant
# challenging
# difficult patient
# refused several exams
# True positives: 5
# False positives: 2
# True negatives: 499
# False negatives: 0
# 0.8333333333333333

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[26]["Completion"]

chat2 = ['noncompliance', 'refused', 'challenging demeanor', 'contradictory descriptions', 'resistant', 'difficulty providing a clear timeline of symptoms']

answer2 = ['noncompliance', 'refusal to adhere to recommended dietary changes', 'resistant and challenging demeanor regarding diabetes education', 'contradictory descriptions of dietary habits', 'difficulty in providing a clear timeline of symptoms']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliance
# challenging demeanor
# contradictory descriptions
# resistant
# True positives: 5
# False positives: 1
# True negatives: 500
# False negatives: 0
# 0.9090909090909091

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[27]["Completion"]

chat2 = ['nonadherent', 'medication nonadherence', 'noncompliant', 'uncooperative']

answer2 = ['medication nonadherence', 'noncompliance', 'uncooperative', 'history of nonadherence', 'failure to do so could result in further complications', 'frequently missed scheduled appointments']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# medication nonadherence
# uncooperative
# True positives: 2
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.4

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[28]["Completion"]

chat2 = ['noncompliant', 'refused', 'challenging', 'contradicting themselves', 'difficulty maintaining consistent medical appointments', 'lives with parents', 'mentions spending a lot of time at fast-food restaurants', 'demonstrated challenging behavior', 'refused a planned exam', 'inconsistent responses']

answer2 = ['poor control over his diabetes', 'medication nonadherence', 'refusal of insulin therapy', 'challenging behavior', 'difficult to engage in effective diabetes education', 'contradictory statements about diet and medication adherence', 'challenging during examination', 'noncompliant']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# refused
# challenging
# True positives: 2
# False positives: 8
# True negatives: 487
# False negatives: 6
# 0.22222222222222224

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[29]["Completion"]

chat2 = ['obese', 'noncompliant', 'resistant', 'challenging', 'narcotic dependence', 'frequent visitor to ED', 'alcoholic', 'inconsistent responses']

answer2 = ['obese male', 'noncompliant behavior', 'resistant and challenging attitude', 'remains noncompliant', 'poorly controlled Type 2 Diabetes', 'poor diabetes management', 'noncompliance only complicates your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# obese
# noncompliant
# resistant
# challenging
# True positives: 4
# False positives: 4
# True negatives: 494
# False negatives: 3
# 0.5333333333333333

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[30]["Completion"]

chat2 = ['noncompliant', 'refused', 'uncooperative', 'challenging', 'medication nonadherence']

answer2 = ['noncompliant', 'refused to provide more details', 'difficult to ascertain due to patient noncompliance', 'lack of cooperation from the patient', 'patient’s refusal to provide an accurate history', 'abnormally short for age', 'compliance issues', 'medication nonadherence', 'uncooperative during the exam', 'challenging at times', 'difficulties during the exam', 'noncompliance and difficulties during the exam']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# refused
# uncooperative
# challenging
# medication nonadherence
# True positives: 5
# False positives: 0
# True negatives: 494
# False negatives: 7
# 0.5882352941176471

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[31]["Completion"]

chat2 = ['difficult patient', 'resistant', 'contradicting themselves', 'refused', 'challenging behavior', 'noncompliant', 'noncompliance with school regulations', 'noncompliant with recommended genetic counseling', 'refused initial blood work', 'exhibited challenging behavior throughout hospital stay', 'refusing treatment', 'resistance towards medical advice']

answer2 = ['difficult patient by her own admission', 'resistant to undergoing the necessary growth hormone stimulation tests', 'contradicting herself', 'noncompliance with school regulations', 'noncompliant with recommended genetic counseling', 'challenging behavior throughout her hospital stay', 'refusing treatment', 'resistance towards medical advice', 'significantly retarded growth', 'difficult to manage due to her noncompliance with recommended diagnostic procedures']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 9

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult patient
# resistant
# challenging behavior
# noncompliant
# noncompliance with school regulations
# noncompliant with recommended genetic counseling
# refusing treatment
# resistance towards medical advice
# True positives: 9
# False positives: 3
# True negatives: 497
# False negatives: 1
# 0.8181818181818182

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[32]["Completion"]

chat2 = ['known alcoholic', 'narcotic-dependent', 'difficult', 'resistant', 'providing vague and inconsistent details about his symptoms', 'compliance issues', 'refused', 'reluctantly agreed upon', 'substance abuse counseling']

answer2 = ['known alcoholic and narcotic-dependent patient', 'difficult and resistant', 'vague and inconsistent details about his symptoms', 'noncompliant', 'resistant behavior towards dietary changes', 'reluctantly agreed upon', 'compliance issues', 'continued resistance to medical advice could result in significant health deterioration', 'history of narcotic dependency and alcohol use disorder', 'refusal to complete recommended exams']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# known alcoholic
# narcotic-dependent
# difficult
# resistant
# providing vague and inconsistent details about his symptoms
# compliance issues
# reluctantly agreed upon
# substance abuse counseling
# True positives: 5
# False positives: 4
# True negatives: 492
# False negatives: 5
# 0.5263157894736842

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[33]["Completion"]

chat2 = ['nonadherent', 'noncompliant', 'refused', 'frequent visitor to ED', 'narcotic dependence', 'obese', 'alcoholic', 'inconsistent responses']

answer2 = ['nonadherence to antihypertensive medications', 'refused to acknowledge the importance of consistent medication intake', 'noncompliant with dietary restrictions', 'smoker, 1 pack/day for 20 years', 'noncompliance with medications', 'difficulty in adhering to prescribed diet and medication regimen', 'refused to acknowledge the importance of these lifestyle changes at the time of discharge', 'highlighting a pattern of nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 2

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# refused
# True positives: 2
# False positives: 6
# True negatives: 489
# False negatives: 6
# 0.25

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[34]["Completion"]

chat2 = ['challenging', 'nonadherent', 'compliance issues', 'resistance to medical advice', 'possible Growth Hormone Deficiency', 'active, albeit resistant to certain interventions.', 'mental status: Stable']

answer2 = ['challenging at times', 'signs of medication nonadherence', 'compliance issues when faced with dietary recommendations', 'declined certain examinations', 'generally difficult to manage', 'showing resistance to medical advice', 'resistant to certain interventions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# compliance issues
# resistance to medical advice
# True positives: 3
# False positives: 4
# True negatives: 493
# False negatives: 4
# 0.42857142857142855

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[35]["Completion"]

chat2 = ['noncompliant', 'refused', 'challenging', 'inconsistent responses', 'contradicting themselves']

answer2 = ['inconsistent responses', 'difficulties in assessing lifestyle contributions to their condition', 'noncompliant with recommendations for nutritional supplements', 'noncompliance with dietary recommendations', 'challenges in managing patient expectations and compliance', 'repeatedly addressed medication nonadherence', 'refusal to follow prescribed nutritional guidance', 'challenging behavior when discussing the importance of consistent and balanced meals', 'contradicting previously provided information about daily habits', 'faced challenges related to his growth due to noncompliance with nutritional and health recommendations', 'Compliance with these recommendations will be reviewed']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# inconsistent responses
# faced challenges related to his growth due to noncompliance with nutritional and health recommendations
# falses: 2
# noncompliant
# challenging
# True positives: 4
# False positives: 1
# True negatives: 495
# False negatives: 5
# 0.5714285714285714

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[36]["Completion"]

chat2 = ['noncompliant', 'medication nonadherence', 'difficult', 'challenging', 'refused', 'resistance']

answer2 = ['noncompliant with the treatment recommendations', 'demonstrated medication nonadherence', 'difficult and challenging with the staff', 'refused the initial exam', 'resistance to follow medical advice']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# medication nonadherence
# difficult
# challenging
# refused
# resistance
# True positives: 6
# False positives: 0
# True negatives: 502
# False negatives: -1
# 1.0909090909090908

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[37]["Completion"]

chat2 = ['non-adherence', 'noncompliant', 'frequent non-adherence', 'reluctance', 'resistant', 'variable success', 'obesity']

answer2 = ['frequent non-adherence to recommended medical interventions', 'pattern reminiscent of past noncompliance', 'failing to monitor her blood pressure regularly', 'elevated cholesterol levels and A1C indicative of poor dietary control and medication nonadherence', 'frequently resistant to suggestions for lifestyle adjustments', 'voiced reluctance towards new medication regimens', 'reluctant to make necessary changes', 'managed with variable success due to similar compliance issues', 'despite previous difficulties and resistance to medication adjustments']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# non-adherence
# frequent non-adherence
# reluctance
# resistant
# variable success
# obesity
# True positives: 5
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.6250000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[38]["Completion"]

chat2 = ['narcotic dependent', 'inconsistent', 'contradicting themselves', 'noncompliant', 'difficult', 'refused', 'frequent visitor to ED', 'alcoholic', 'obese']

answer2 = ['known narcotic dependent', "inconsistent account of the pain's onset", 'unable to give a clear timeline', 'contradicting herself', 'frequent visits to the emergency department for pain management', 'heavy smoker', 'using narcotics frequently', 'spent time around locations with easy access to narcotics', 'difficult and provided limited information', 'appeared agitated and noncompliant during examination', 'labeled as a difficult patient', 'noncompliant behavior', 'refusal to undergo recommended exams', 'managed with challenges regarding pain control and medication adherence', 'difficulties with compliance and managing your pain medication', 'narcotic dependency', 'challenging']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# inconsistent account of the pain's onset
# spent time around locations with easy access to narcotics
# managed with challenges regarding pain control and medication adherence
# falses: 3
# narcotic dependent
# inconsistent
# noncompliant
# difficult
# True positives: 5
# False positives: 4
# True negatives: 488
# False negatives: 9
# 0.43478260869565216

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[39]["Completion"]

chat2 = ['frequent ED visitor', 'noncompliant demeanor', 'inconsistent medication adherence', 'challenging and noncompliant behavior', 'previous misunderstandings about her medication adherence', 'inconsistencies in use', 'noted inconsistencies in use', 'continued use of Levetiracetam with noted inconsistencies', 'Mental Status: Stable but somewhat noncompliant.', 'active participation and adherence to the prescribed treatment plan']

answer2 = ['so-called "frequent ED visitor"', 'poorly managed', 'inconsistent medication adherence', 'noncompliant demeanor', 'frequent mentions of previous "misunderstandings" about her medication adherence', 'challenging and noncompliant behavior', 'inconsistent historian', 'nonadherence discussed at length', 'somewhat noncompliant', 'frequently contradicting previous statements about medication intake']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# so-called "frequent ED visitor"
# falses: 1
# frequent ED visitor
# noncompliant demeanor
# inconsistent medication adherence
# challenging and noncompliant behavior
# inconsistencies in use
# noted inconsistencies in use
# Mental Status: Stable but somewhat noncompliant.
# active participation and adherence to the prescribed treatment plan
# True positives: 5
# False positives: 5
# True negatives: 492
# False negatives: 4
# 0.5263157894736842

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[40]["Completion"]

chat2 = ['difficult patient', 'uncooperative', 'resistant', 'failed to follow up', 'ignored medical advice', 'noncompliance', 'challenging', 'refused', 'resistant to discussing potential preventative measures for future pregnancies']

answer2 = ['a difficult patient', 'ignored medical advice', 'resistant to suggestions for improving her health', 'failed to follow up on recommended tests', 'ignored dietary advice', 'uncooperative with staff', 'noncompliance', 'resistance to discussing potential preventative measures for future pregnancies', 'resistant', 'refusal to accept medical advice', 'resistant to the idea of counseling', 'Ignoring the reality of your health and instructions will only lead to further complications']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# failed to follow up on recommended tests
# ignored dietary advice
# falses: 2
# difficult patient
# uncooperative
# resistant
# ignored medical advice
# noncompliance
# challenging
# True positives: 7
# False positives: 2
# True negatives: 496
# False negatives: 3
# 0.7368421052631577

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[41]["Completion"]

chat2 = ['noncompliant', 'difficult', 'frequent visitor to ED', 'obese', 'inconsistent responses']

answer2 = ['a known noncompliant patient', 'failing to maintain a healthy diet', 'Her story was difficult to follow, demonstrating an inability to give a clear timeline', 'frequent visits', 'labeled as a difficult patient due to her noncompliance', 'refused an initial exam', 'reluctance to follow medical advice for managing her diabetes', 'resistant to following directions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# difficult
# True positives: 3
# False positives: 2
# True negatives: 494
# False negatives: 5
# 0.4615384615384615

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[42]["Completion"]

chat2 = ['obese', 'noncompliant', 'challenging', 'difficult', 'refusing', 'medication nonadherence']

answer2 = ['a notably obese male patient', 'noncompliance with recommended regimens', 'refusing dietary adjustments', 'labeling him a difficult and challenging patient for our dietary team', 'challenging attitude towards the medical staff', 'repeated refusal to participate in recommended physical therapy sessions', 'noncompliance and medication adherence issues have been a recurrent theme']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# obese
# challenging
# difficult
# refusing
# True positives: 5
# False positives: 1
# True negatives: 498
# False negatives: 2
# 0.7692307692307692

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[43]["Completion"]

chat2 = ['noncompliant', 'history of noncompliance', 'disregard for prior medical advice', 'resistant attitude towards treatment', 'frequent flyer', 'inconsistent history reporting', 'refused to undergo recommended examination procedures initially']

answer2 = ['disregard for prior medical advice', 'history of noncompliance with treatment plans', 'resistant attitude towards treatment', 'frequent flyer in our department', 'pattern of disregarding medical advice', 'difficulty in managing the patient due to inconsistent history reporting', 'refusal to undergo recommended examination procedures initially', 'previous resistance to comprehensive sinusitis management', 'due to your history of noncompliance and the severity of your condition']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 6

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# history of noncompliance
# disregard for prior medical advice
# resistant attitude towards treatment
# frequent flyer
# inconsistent history reporting
# True positives: 6
# False positives: 1
# True negatives: 497
# False negatives: 3
# 0.75

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[44]["Completion"]

chat2 = ['difficult patient', 'frequent visitor to ED', 'medication nonadherence', 'noncompliant', 'reluctance towards proper management', 'refused several exams', 'unreliable historian behavior', 'resistance', 'obese']

answer2 = ['known for being a difficult patient', 'in our ED frequently', 'history of medication nonadherence', 'acknowledged but blamed on the complex nature of his treatment regime', 'noncompliant', 'pattern of reluctance towards proper management', 'repeatedly demonstrated a pattern of medication nonadherence', 'refused several exams during his stay', 'unreliable historian behavior', 'met with resistance', 'complicating efforts to adjust his treatment plan']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 7

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# difficult patient
# medication nonadherence
# noncompliant
# reluctance towards proper management
# refused several exams
# unreliable historian behavior
# resistance
# True positives: 7
# False positives: 2
# True negatives: 495
# False negatives: 4
# 0.7000000000000001

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[45]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'resistant', 'challenging', 'difficult case', 'frequent flyer']

answer2 = ['parents have expressed frustration over his "stubborn eating habits"', 'resistance to adhere to dietary recommendations', 'describing Dee as "resistant"', 'known difficult case', 'noncompliance with dietary and medication regimes', 'challenging', 'frequently missing appointments', 'resisting dietary adjustments necessary for his condition', 'frequent flyer status in our clinic', 'not taken as prescribed', 'history of noncompliance and resistance to medical advice', 'compliance with his asthma management plan is equally crucial to avoid further frequent flyer visits to the emergency department', 'constant nonadherence']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 4

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# resistance to adhere to dietary recommendations
# constant nonadherence
# falses: 2
# resistant
# challenging
# difficult case
# frequent flyer
# True positives: 4
# False positives: 2
# True negatives: 492
# False negatives: 7
# 0.4705882352941177

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[46]["Completion"]

chat2 = ['disconcerting', 'difficult', 'contradictions', 'resistance', 'repeated hospital visits for minor complaints', 'attention-seeking behavior', 'keeps to himself', 'refused to fully disclose', 'noncompliant', 'frequent refusals for recommended exams', 'impeded', 'challenging behavior during his stay', 'noncompliant ', 'minimizing unnecessary visits would be prudent']

answer2 = ['a disconcerting and difficult patient', 'Efforts to delve deeper into the situation were met with resistance', 'Frequently seen in the local ED for various minor issues, which might suggest attention-seeking behavior', 'noncompliant behavior and frequent refusals for recommended exams', 'challenging behavior during his stay', 'noncompliant', 'contradictions']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 9

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# disconcerting
# difficult
# contradictions
# resistance
# repeated hospital visits for minor complaints
# attention-seeking behavior
# keeps to himself
# noncompliant
# frequent refusals for recommended exams
# impeded
# challenging behavior during his stay
# noncompliant
# minimizing unnecessary visits would be prudent
# True positives: 9
# False positives: 5
# True negatives: 498
# False negatives: -2
# 0.8571428571428572

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[47]["Completion"]

chat2 = ['noncompliant', 'challenging', 'refused', 'nonadherent', 'inconsistent responses']

answer2 = ['challenging when questioned about the timeline of symptoms', 'noncompliance with cessation support', 'appeared noncompliant and somewhat challenging during the exam', 'patient refused further imaging', 'complicated by noncompliance with medication and refusal to participate in further diagnostic exams', 'met with resistance', 'challenging to implement', 'reinforced importance but patient was resistant', 'nonadherence noted', 'advised on compliance', 'patient was challenging about taking regularly', 'difficult', 'limited due to noncompliance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# noncompliant
# challenging
# refused
# True positives: 3
# False positives: 2
# True negatives: 489
# False negatives: 10
# 0.33333333333333337

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[48]["Completion"]

chat2 = ['obese', 'noncompliant', 'refused', 'difficult patient', 'disruptive pattern of behavior', 'mental health component', 'reluctance', 'fast food']

answer2 = ['pattern of noncompliance with previously recommended dietary and physical activity interventions', 'appeared well but overweight', 'obese', 'met with limited patient engagement', 'displayed a disruptive pattern of behavior by being a difficult patient', 'refused several suggestions from the dietary team', 'reluctance to discuss or engage in mental health support options', 'previous reluctance']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 5

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# obese
# refused
# difficult patient
# disruptive pattern of behavior
# mental health component
# reluctance
# fast food
# True positives: 5
# False positives: 3
# True negatives: 495
# False negatives: 3
# 0.625

# %%
import pandas as pd
df = pd.read_csv("/Users/sagewong/git/StigmatizingLanguageProject/FinalFinalAnnnotatedData.csv")

stringData = df.iloc[49]["Completion"]

chat2 = ['noncompliant', 'nonadherent', 'challenging', 'refused', 'inconsistent responses', 'frequent visitor to ED', 'narcotic dependence', 'obese', 'alcoholic']

answer2 = ['history of previous similar episodes, often refuses to seek early treatment', 'medication nonadherence', 'frequent smoker, consuming a pack a day', 'noncompliant with previous advice to quit', 'showed a challenging attitude towards treatment', 'refused anti-inflammatory medication on two occasions', 'declined spirometry, citing discomfort', 'noncompliance has delayed his recovery process', 'somewhat challenging behavior during this hospital stay']

falses = 0
for i in answer2:
    if i.upper() not in stringData.upper():
        falses += 1
        print(i)
print("falses: " + str(falses))
for i in chat2:
    if i in stringData:
        print(i)

matching = 3

true_positive = matching
false_positive = len(chat2) - matching
true_negative = df.iloc[1]["Completion"].count(" ") - false_positive - (len(answer2) -falses - matching)
false_negative = len(answer2) - matching - falses

precision = true_positive/(true_positive + false_positive)
recall = true_positive/(true_positive + false_negative)

f1_score = (2*precision*recall)/(precision+recall)

print("True positives: " + str(true_positive))
print("False positives: " + str(false_positive))
print("True negatives: " + str(true_negative))
print("False negatives: " + str(false_negative))
print(f1_score)
# Out:
# falses: 0
# challenging
# refused
# True positives: 3
# False positives: 6
# True negatives: 489
# False negatives: 6
# 0.3333333333333333
